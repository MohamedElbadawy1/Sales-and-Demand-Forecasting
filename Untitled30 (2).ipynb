# %%
import pandas as pd
import numpy as np

# %%
sales =pd.read_csv("C:/Users/DeLL/Downloads/Global_Superstore2.csv",encoding='latin-1')

# %%
sales.shape
# Out:
# (51290, 24)

# %%
sales.head()
# Out:
#    Row ID         Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891  31-07-2012  31-07-2012      Same Day    RH-19495
# 1   26341    IN-2013-77878  05-02-2013  07-02-2013  Second Class    JR-16210
# 2   25330    IN-2013-71249  17-10-2013  18-10-2013   First Class    CR-12730
# 3   13524  ES-2013-1579342  28-01-2013  30-01-2013   First Class    KM-16375
# 4   47221     SG-2013-4320  05-11-2013  06-11-2013      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %%
sales.describe()
# Out:
#             Row ID   Postal Code         Sales      Quantity      Discount  \
# count  51290.00000   9994.000000  51290.000000  51290.000000  51290.000000
# mean   25645.50000  55190.379428    246.490581      3.476545      0.142908
# std    14806.29199  32063.693350    487.565361      2.278766      0.212280
# min        1.00000   1040.000000      0.444000      1.000000      0.000000
# 25%    12823.25000  23223.000000     30.758625      2.000000      0.000000
# 50%    25645.50000  56430.500000     85.053000      3.000000      0.000000
# 75%    38467.75000  90008.000000    251.053200      5.000000      0.200000
# max    51290.00000  99301.000000  22638.480000     14.000000      0.850000
#
#              Profit  Shipping Cost
# count  51290.000000   51290.000000
# mean      28.610982      26.375915
# std      174.340972      57.296804
# min    -6599.978000       0.000000
# 25%        0.000000       2.610000
# 50%        9.240000       7.790000
# 75%       36.810000      24.450000
# ...

# %%
sales.tail()
# Out:
#        Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 51285   29002   IN-2014-62366  19-06-2014  19-06-2014        Same Day
# 51286   35398  US-2014-102288  20-06-2014  24-06-2014  Standard Class
# 51287   40470  US-2013-155768  02-12-2013  02-12-2013        Same Day
# 51288    9596  MX-2012-140767  18-02-2012  22-02-2012  Standard Class
# 51289    6147  MX-2012-134460  22-05-2012  26-05-2012    Second Class
#
#       Customer ID     Customer Name      Segment      City       State  ...  \
# 51285    KE-16420   Katrina Edelman    Corporate      Kure   Hiroshima  ...
# 51286    ZC-21910  Zuschuss Carroll     Consumer   Houston       Texas  ...
# 51287    LB-16795    Laurel Beltran  Home Office    Oxnard  California  ...
# 51288    RB-19795        Ross Baird  Home Office  Valinhos   São Paulo  ...
# 51289    MC-18100     Mick Crebagga     Consumer  Tipitapa     Managua  ...
#
#             Product ID         Category Sub-Category  \
# ...

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  object
#  3   Ship Date       51290 non-null  object
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
# ...

# %%
sales.drop(columns=['Row ID','Order ID','Customer ID','Product ID','Postal Code'],inplace=True)

# %%
sales['Order Date'] = pd.to_datetime(sales['Order Date'])
sales['Ship Date'] = pd.to_datetime(sales['Ship Date'])
# Out:
# C:\Users\DeLL\AppData\Local\Temp\ipykernel_19396\3665113768.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   sales['Order Date'] = pd.to_datetime(sales['Order Date'])
# C:\Users\DeLL\AppData\Local\Temp\ipykernel_19396\3665113768.py:2: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   sales['Ship Date'] = pd.to_datetime(sales['Ship Date'])

# %%
sales.dtypes
# Out:
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer Name             object
# Segment                   object
# City                      object
# State                     object
# Country                   object
# Market                    object
# Region                    object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %%
sales.isna().sum()
# Out:
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer Name     0
# Segment           0
# City              0
# State             0
# Country           0
# Market            0
# Region            0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# Shipping Cost     0
# Order Priority    0
# dtype: int64

# %%
sales['Month']=sales['Order Date'].dt.month
sales['Quarter']=sales['Order Date'].dt.quarter
sales['Year']=sales['Order Date'].dt.year
sales['Day_of_Week']=sales['Order Date'].dt.dayofweek
sales['Is_Weekend']=sales['Day_of_Week'].isin([5,6]).astype(int)

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar 
cal=USFederalHolidayCalendar()
holidays = cal.holidays(start=sales['Order Date'].min(),end=sales['Order Date'].max())
sales['Is_Holiday']=sales['Order Date'].isin(holidays).astype(int)

# %%
sales['Season']=sales['Month'].apply(lambda x : 'Winter'if x in [12,1,2]else
                                     'Spring' if x in [3,4,5]else
                                     'Summer' if x in [6,7,8]else
                                     'fail')

# %%
sales['Season']=sales['Season'].astype('category')
sales.head()
# Out:
#   Order Date  Ship Date     Ship Mode     Customer Name      Segment  \
# 0 2012-07-31 2012-07-31      Same Day       Rick Hansen     Consumer
# 1 2013-02-05 2013-02-07  Second Class     Justin Ritter    Corporate
# 2 2013-10-17 2013-10-18   First Class      Craig Reiter     Consumer
# 3 2013-01-28 2013-01-30   First Class  Katherine Murray  Home Office
# 4 2013-11-05 2013-11-06      Same Day       Rick Hansen     Consumer
#
#             City            State        Country  Market   Region  ...  \
# 0  New York City         New York  United States      US     East  ...
# 1     Wollongong  New South Wales      Australia    APAC  Oceania  ...
# 2       Brisbane       Queensland      Australia    APAC  Oceania  ...
# 3         Berlin           Berlin        Germany      EU  Central  ...
# 4          Dakar            Dakar        Senegal  Africa   Africa  ...
#
#      Profit Shipping Cost Order Priority  Month  Quarter  Year  Day_of_Week  \
# ...

# %%
sales.isna().sum()
# Out:
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer Name     0
# Segment           0
# City              0
# State             0
# Country           0
# Market            0
# Region            0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# Shipping Cost     0
# Order Priority    0
# Month             0
# Quarter           0
# Year              0
# Day_of_Week       0
# Is_Weekend        0
# Is_Holiday        0
# Season            0
# dtype: int64

# %%
sales['State'].unique()
# Out:
# array(['New York', 'New South Wales', 'Queensland', ..., 'Manicaland',
#        'Kabarole', 'Matabeleland North'], dtype=object)

# %%
sales['Ship Mode'].unique()
# Out:
# array(['Same Day', 'Second Class', 'First Class', 'Standard Class'],
#       dtype=object)

# %%
pd.set_option('display.max_columns', None)
sales.sample(8)
# Out:
#       Order Date  Ship Date       Ship Mode     Customer Name      Segment  \
# 42613 2012-07-05 2012-07-10  Standard Class      Mitch Webber     Consumer
# 47232 2013-01-18 2013-01-20    Second Class    Julie Prescott  Home Office
# 37524 2014-02-03 2014-02-08  Standard Class          John Lee     Consumer
# 23416 2013-04-29 2013-05-01     First Class     Jas O'Carroll     Consumer
# 6068  2011-09-23 2011-09-25     First Class  Zuschuss Carroll     Consumer
# 27702 2014-06-04 2014-06-09  Standard Class     Greg Matthias     Consumer
# 24530 2014-07-28 2014-08-01    Second Class   Mike Gockenbach     Consumer
# 32186 2012-03-13 2012-03-18  Standard Class  Valerie Takahito  Home Office
#
#                City            State        Country  Market   Region  \
# 42613  Philadelphia     Pennsylvania  United States      US     East
# 47232    Alexandria  Al Iskandariyah          Egypt  Africa   Africa
# 37524   Los Angeles       California  United States      US     West
# ...

# %%
sales.columns
# Out:
# Index(['Order Date', 'Ship Date', 'Ship Mode', 'Customer Name', 'Segment',
#        'City', 'State', 'Country', 'Market', 'Region', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority', 'Month', 'Quarter', 'Year',
#        'Day_of_Week', 'Is_Weekend', 'Is_Holiday', 'Season'],
#       dtype='object')

# %%
sales['Customer Name'].value_counts()
# Out:
# Customer Name
# Muhammed Yedwab    108
# Steven Ward        106
# Gary Hwang         102
# Patrick O'Brill    102
# Bill Eplett        102
#                   ...
# Emily Burns         35
# David Bremer        34
# Darren Budd         31
# Nicole Brennan      31
# Michael Oakman      29
# Name: count, Length: 795, dtype: int64

# %%
nationality_Muhammes=sales[sales['Customer Name']=='Muhammed Yedwab']

# %%
pd.set_option('display.max_columns',None)
nationality_Muhammes.sample(1)
# Out:
#      Order Date  Ship Date       Ship Mode    Customer Name    Segment  \
# 4498 2012-09-18 2012-09-23  Standard Class  Muhammed Yedwab  Corporate
#
#           City                   State  Country Market   Region    Category  \
# 4498  Dortmund  North Rhine-Westphalia  Germany     EU  Central  Technology
#
#      Sub-Category                 Product Name    Sales  Quantity  Discount  \
# 4498      Copiers  Brother Wireless Fax, Color  1140.75         3       0.0
#
#       Profit  Shipping Cost Order Priority  Month  Quarter  Year  Day_of_Week  \
# 4498  239.49          72.86         Medium      9        3  2012            1
#
#       Is_Weekend  Is_Holiday Season
# 4498           0           0   fail

# %%
sales['Product Name'].value_counts()
# Out:
# Product Name
# Staples                                                             227
# Cardinal Index Tab, Clear                                            92
# Eldon File Cart, Single Width                                        90
# Rogers File Cart, Single Width                                       84
# Ibico Index Tab, Clear                                               83
#                                                                    ...
# Penpower WorldCard Pro Card Scanner                                   1
# Cisco SPA525G2 5-Line IP Phone                                        1
# Park Ridge Embossed Executive Business Envelopes                      1
# Rediform S.O.S. Phone Message Books                                   1
# Eureka Disposable Bags for Sanitaire Vibra Groomer I Upright Vac      1
# Name: count, Length: 3788, dtype: int64

# %%
import matplotlib.pyplot as plt 
import seaborn as sns 
import plotly.express as px

# %%
plt.hist(sales['Ship Mode'],bins=7)
plt.title('Ship Mode')
plt.show()

# %%
sales['Market'].value_counts()
# Out:
# Market
# APAC      11002
# LATAM     10294
# EU        10000
# US         9994
# EMEA       5029
# Africa     4587
# Canada      384
# Name: count, dtype: int64

# %%
plt.hist(sales['Market'],bins=20)
plt.title('Marker')
plt.show()

# %%
sales['Year'].value_counts()
# Out:
# Year
# 2014    17531
# 2013    13799
# 2012    10962
# 2011     8998
# Name: count, dtype: int64

# %%
plt.hist(sales['Year'],bins=7)
plt.title('Year')
plt.show()

# %%
sales['Month'].value_counts()
# Out:
# Month
# 11    6342
# 12    6302
# 9     5975
# 6     5331
# 8     5078
# 10    4490
# 5     3747
# 7     3166
# 4     3057
# 3     3035
# 1     2599
# 2     2168
# Name: count, dtype: int64

# %%
plt.xticks(range(1,13))
plt.hist(sales['Month'],bins=25)
plt.show()

# %%
pd.set_option('display.max_columns',None)
sales.sample(6)
# Out:
#       Order Date  Ship Date       Ship Mode       Customer Name    Segment  \
# 51152 2014-01-31 2014-02-05  Standard Class     Sandra Flanagan   Consumer
# 28286 2011-12-27 2011-12-28     First Class  Benjamin Patterson   Consumer
# 45730 2013-08-05 2013-08-08     First Class        Joseph Airdo   Consumer
# 42671 2014-06-18 2014-06-22  Standard Class       Arthur Gainer   Consumer
# 41805 2013-11-23 2013-11-27  Standard Class          Todd Boyes  Corporate
# 47941 2013-04-22 2013-04-25     First Class        Duane Noonan   Consumer
#
#                 City          State        Country  Market  Region  \
# 51152          Lagos          Lagos        Nigeria  Africa  Africa
# 28286        Goiânia          Goiás         Brazil   LATAM   South
# 45730          Bursa          Bursa         Turkey    EMEA    EMEA
# 42671  Dar es Salaam  Dar Es Salaam       Tanzania  Africa  Africa
# 41805  New York City       New York  United States      US    East
# ...

# %%
sales['Segment'].value_counts()
# Out:
# Segment
# Consumer       26518
# Corporate      15429
# Home Office     9343
# Name: count, dtype: int64

# %%
sales['Country'].value_counts()
# Out:
# Country
# United States    9994
# Australia        2837
# France           2827
# Mexico           2644
# Germany          2065
#                  ...
# Bahrain             2
# South Sudan         2
# Chad                2
# Burundi             2
# Eritrea             2
# Name: count, Length: 147, dtype: int64

# %%
sales['Category'].value_counts()
# Out:
# Category
# Office Supplies    31273
# Technology         10141
# Furniture           9876
# Name: count, dtype: int64

# %%
plt.hist(sales['Category'],bins=5)
plt.title('Category')
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.regplot(x='Year',y='Sales',data=sales)
plt.show()

# %%
upper_20000=sales[sales['Sales']>20000]
upper_20000
# Out:
#       Order Date  Ship Date       Ship Mode Customer Name      Segment  \
# 12887 2011-03-18 2011-03-23  Standard Class   Sean Miller  Home Office
#
#                City    State        Country Market Region    Category  \
# 12887  Jacksonville  Florida  United States     US  South  Technology
#
#       Sub-Category                                       Product Name  \
# 12887     Machines  Cisco TelePresence System EX90 Videoconferenci...
#
#           Sales  Quantity  Discount     Profit  Shipping Cost Order Priority  \
# 12887  22638.48         6       0.5 -1811.0784          24.29         Medium
#
#        Month  Quarter  Year  Day_of_Week  Is_Weekend  Is_Holiday  Season
# 12887      3        1  2011            4           0           0  Spring

# %%
sales['Sub-Category'].value_counts()
# Out:
# Sub-Category
# Binders        6152
# Storage        5059
# Art            4883
# Paper          3538
# Chairs         3434
# Phones         3357
# Furnishings    3170
# Accessories    3075
# Labels         2606
# Envelopes      2435
# Supplies       2425
# Fasteners      2420
# Bookcases      2411
# Copiers        2223
# Appliances     1755
# Machines       1486
# Tables          861
# Name: count, dtype: int64

# %%
EDA_1=sales[sales['Country']=='United States']
EDA_1
# Out:
#       Order Date  Ship Date       Ship Mode     Customer Name      Segment  \
# 0     2012-07-31 2012-07-31        Same Day       Rick Hansen     Consumer
# 8     2014-10-14 2014-10-21  Standard Class         Jane Waco    Corporate
# 9     2012-01-28 2012-01-31    Second Class       Joseph Holt     Consumer
# 10    2011-04-05 2011-04-09    Second Class      Greg Maxwell    Corporate
# 16    2014-11-03 2014-11-06    Second Class     Thomas Boland    Corporate
# ...          ...        ...             ...               ...          ...
# 51270 2011-10-18 2011-10-23    Second Class       Ivan Gibson     Consumer
# 51276 2014-06-09 2014-06-13  Standard Class      Dorris liebe    Corporate
# 51277 2012-12-25 2012-12-30    Second Class      Ralph Arnett     Consumer
# 51286 2014-06-20 2014-06-24  Standard Class  Zuschuss Carroll     Consumer
# 51287 2013-12-02 2013-12-02        Same Day    Laurel Beltran  Home Office
#
# ...

# %%
plt.xticks(range(1,13))
plt.hist(EDA_1['Month'],bins=25)
plt.show()

# %%
total_sales_1 = EDA_1['Sales'].sum()
total_sales_1
# Out:
# 2297200.8603

# %%
EDA_1['State'].value_counts()
# Out:
# State
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Virginia                 224
# Arizona                  224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Missouri                  66
# Oklahoma                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
plt.figure(figsize=(10,10))
plt.barh(EDA_1['State'], EDA_1['Sales'], color='skyblue') 
plt.title('Sales in US cities')
plt.show()

# %%
sales['Country'].value_counts()
# Out:
# Country
# United States    9994
# Australia        2837
# France           2827
# Mexico           2644
# Germany          2065
#                  ...
# Bahrain             2
# South Sudan         2
# Chad                2
# Burundi             2
# Eritrea             2
# Name: count, Length: 147, dtype: int64

# %%
EDA_2=sales[sales['Country']=='Australia']
EDA_2.sample(1)
# Out:
#      Order Date  Ship Date       Ship Mode Customer Name    Segment   City  \
# 2741 2011-12-12 2011-12-16  Standard Class  Matt Connell  Corporate  Perth
#
#                   State    Country Market   Region   Category Sub-Category  \
# 2741  Western Australia  Australia   APAC  Oceania  Furniture    Bookcases
#
#                       Product Name     Sales  Quantity  Discount   Profit  \
# 2741  Bush Classic Bookcase, Metal  1112.778         3       0.1  407.988
#
#       Shipping Cost Order Priority  Month  Quarter  Year  Day_of_Week  \
# 2741         106.29           High     12        4  2011            0
#
#       Is_Weekend  Is_Holiday  Season
# 2741           0           0  Winter

# %%
plt.figure(figsize=(10,5))
plt.barh(EDA_2['State'],EDA_2['Sales'],color='r')
plt.show()

# %%
plt.figure(figsize=(10,12))
plt.barh(EDA_2['City'],EDA_2['Sales'],color='r')
plt.title('Sales in Australia cities ')
plt.show()

# %%
sales_2011_AS=sales[(sales['Country']=='Australia')&(sales['Year']==2011)]
sales_2012_AS=sales[(sales['Country']=='Australia')&(sales['Year']==2012)]
sales_2013_AS=sales[(sales['Country']=='Australia')&(sales['Year']==2013)]
sales_2014_AS=sales[(sales['Country']=='Australia')&(sales['Year']==2014)]

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 18))

axs[0, 0].barh(sales_2011_AS['City'], sales_2011_AS['Sales'], color='red')
axs[0, 0].set_title('Sales 2011')

axs[0, 1].barh(sales_2012_AS['City'], sales_2012_AS['Sales'], color='red')
axs[0, 1].set_title('Sales 2012')

axs[1, 0].barh(sales_2013_AS['City'], sales_2013_AS['Sales'], color='red')
axs[1, 0].set_title('Sales 2013')

axs[1, 1].barh(sales_2014_AS['City'], sales_2014_AS['Sales'], color='red')
axs[1, 1].set_title('Sales 2014')
plt.suptitle('Comparison of Sales in Australian Cities Over the Years', fontsize=16)
plt.tight_layout()
plt.subplots_adjust(hspace=0.1, wspace=0.5) 
plt.show()
